# %% [markdown]
# #    Important Libiraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv('udemy_courses_clean.csv') 
df
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  course_id                                       course_title  \
# 0           0    1070968                 Ultimate Investment Banking Course
# 1           1    1113822  Complete GST Course & Certification - Grow You...
# 2           2    1006314  Financial Modeling for Business Analysts and C...
# 3           3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4           4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True   200
# 1      https://www.udemy.com/goods-and-services-tax/    True    75
# 2  https://www.udemy.com/financial-modeling-for-b...    True    45
# 3  https://www.udemy.com/complete-excel-finance-c...    True    95
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True   200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# course_id               int64
# course_title           object
# url                    object
# is_paid                object
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# clean_course_title     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'clean_course_title'],
#       dtype='object')

# %% [markdown]
# #    Data Cleaning

# %%
df = df.drop('Unnamed: 0', axis=1)  
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3678     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3679    1088178  How To Design A WordPress Website With No Codi...
# 3680     635248                      Learn and Build using Polymer
# 3681     905096  CSS Animations: Create Amazing Effects on Your...
# 3682     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url is_paid price  \
# 0     https://www.udemy.com/ultimate-investment-bank...    True   200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3683 non-null   int64
#  1   course_title         3683 non-null   object
#  2   url                  3683 non-null   object
#  3   is_paid              3683 non-null   object
#  4   price                3683 non-null   object
#  5   num_subscribers      3683 non-null   int64
#  6   num_reviews          3683 non-null   int64
#  7   num_lectures         3683 non-null   int64
#  8   level                3683 non-null   object
#  9   content_duration     3683 non-null   object
#  10  published_timestamp  3683 non-null   object
#  11  subject              3683 non-null   object
#  12  clean_course_title   3663 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 374.2+ KB

# %%
df.isnull().sum()
# Out:
# course_id               0
# course_title            0
# url                     0
# is_paid                 0
# price                   0
# num_subscribers         0
# num_reviews             0
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     0
# subject                 0
# clean_course_title     20
# dtype: int64

# %% [markdown]
# # Subject

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
len(df['subject'].unique())
# Out:
# 4

# %%
df['subject'].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: subject, dtype: int64

# %%
df['subject'].value_counts().plot(kind='barh')
plt.show()

# %%
sns.countplot(x=df['subject'],data=df)
plt.xticks(rotation=45)
plt.show() #using seaborn

# %% [markdown]
# # Subscribers

# %%
df['num_subscribers'].describe()
# Out:
# count      3683.000000
# mean       3193.371165
# std        9498.231406
# min           0.000000
# 25%         110.000000
# 50%         911.000000
# 75%        2537.500000
# max      268923.000000
# Name: num_subscribers, dtype: float64

# %%
subjectSub = df.groupby(df['subject'])['num_subscribers'].sum()
subjectSub
# Out:
# subject
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846719
# Web Development        7980572
# Name: num_subscribers, dtype: int64

# %%
df['num_subscribers'].sum()
# Out:
# 11761186

# %%
df['num_subscribers'].idxmax() #max num of subscribers from which course?
# Out:
# 2832

# %%
df.iloc[2832] #get location for max num of subscribers to know which course
# Out:
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                               Free
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                              10.5 hours
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# clean_course_title                       Learn HTML5 Programming Scratch
# ...

# %% [markdown]
# 'Learn HTML5 Programming From Scratch'  has max number of subscribers

# %% [markdown]
# # Level

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level', '52'], dtype=object)

# %%
f=df['level']=='52' #52 is unwantable
df[f]
# Out:
#       course_id                                       course_title    url  \
# 2066      96698  Learn Classical Guitar Technique and play 'Spa...  000!"
#
#                                           is_paid price  num_subscribers  \
# 2066  https://www.udemy.com/learnguitartoworship/  TRUE               30
#
#       num_reviews  num_lectures level content_duration published_timestamp  \
# 2066         1463            29    52   Beginner Level             3 hours
#
#                   subject                                 clean_course_title
# 2066  Musical Instruments  Learn Classical Guitar Technique play Spanish ...

# %%
df.shape
# Out:
# (3683, 13)

# %%
df = df.drop(index=2066) #To remove all the row which contains level '52'

# %%
df.shape #after removing the row
# Out:
# (3682, 13)

# %%
df['level'].value_counts()
# Out:
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
df['level'].value_counts().plot(kind='bar')
plt.xticks(rotation=45)
plt.show()

# %%
levelSub= df.groupby(['level'])['num_subscribers'].sum()
levelSub
# Out:
# level
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
levelSub.plot(kind='barh')
plt.show()

# %%
levelSubj= pd.DataFrame(df.groupby(['subject'])['level'].value_counts())
levelSubj
# Out:
#                                         level
# subject             level
# Business Finance    All Levels            699
#                     Beginner Level        341
#                     Intermediate Level    128
#                     Expert Level           31
# Graphic Design      All Levels            298
#                     Beginner Level        243
#                     Intermediate Level     57
#                     Expert Level            5
# Musical Instruments Beginner Level        296
#                     All Levels            276
#                     Intermediate Level    101
#                     Expert Level            7
# Web Development     All Levels            659
#                     Beginner Level        391
#                     Intermediate Level    135
#                     Expert Level           15

# %%
levelSubj.plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='level',y='num_subscribers',data=df,hue='subject',ci=None)
plt.show() #using seaborn

# %%
def funcDraw(x): # This func to make it easy for any plot based on level and subject 
    plt.figure(figsize=(20,10))
    sns.barplot(x='level',y=x,data=df,hue='subject',ci=None)
    plt.title('Plot of {} per level per subject'.format(x))
    plt.show() 
    
    
    plt.figure(figsize=(10,10))
    df.groupby('level')[x].sum().plot(kind='pie')
    plt.title('Plot of {} per level per subject'.format(x))
    plt.show()

# %%
funcDraw('num_reviews')

# %% [markdown]
# # Lectures

# %%
funcDraw('num_lectures') #calling func with param i want to plot

# %% [markdown]
# # Price

# %%
df['price'].dtype  #object data type
# Out:
# dtype('O')

# %%
df['price'].unique() #'Free' is problem
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', 'Free', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '110', '135'],
#       dtype=object)

# %%
df['price']=df['price'].str.replace('Free','0')

# %%
df['price']=df['price'].astype(float)#convert from obj to float

# %%
df['price'].describe()
# Out:
# count    3682.000000
# mean       66.010320
# std        60.984167
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
df['price'].idxmax() #index for max price
# Out:
# 0

# %%
df.iloc[0] #get location
# Out:
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                               1.5 hours
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# clean_course_title                    Ultimate Investment Banking Course
# Name: 0, dtype: object

# %%
df['price'].sum()
# Out:
# 243050.0

# %%
grouppedPrice =pd.DataFrame(df.groupby('subject')['price'].sum())
grouppedPrice
# Out:
#                        price
# subject
# Business Finance     82040.0
# Graphic Design       34870.0
# Musical Instruments  33700.0
# Web Development      92440.0

# %%
grouppedPrice.plot(kind='barh',color='darkblue')
plt.show()

# %%
df['Profit']=df['price']*df['num_subscribers']

# %%
df.head() #after add new column ['Profit']
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...    True  200.0
# 1      https://www.udemy.com/goods-and-services-tax/    True   75.0
# 2  https://www.udemy.com/financial-modeling-for-b...    True   45.0
# 3  https://www.udemy.com/complete-excel-finance-c...    True   95.0
# 4  https://www.udemy.com/how-to-maximize-your-pro...    True  200.0
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df['Profit'].describe()
# Out:
# count    3.682000e+03
# mean     2.403537e+05
# std      1.000888e+06
# min      0.000000e+00
# 25%      1.576250e+03
# 50%      2.306500e+04
# 75%      1.184300e+05
# max      2.431680e+07
# Name: Profit, dtype: float64

# %%
df['Profit'].max()
# Out:
# 24316800.0

# %%
df['Profit'].idxmax()
# Out:
# 3235

# %%
df.loc[3235]
# Out:
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                43 hours
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# clean_course_title                                Web Developer Bootcamp
# ...

# %% [markdown]
# 'The Web Developer Bootcamp' Course has the max Profit  "24316800.0"

# %%
grouppedProfit =pd.DataFrame(df.groupby('subject')['Profit'].sum())
grouppedProfit
# Out:
#                           Profit
# subject
# Business Finance     123796395.0
# Graphic Design        76983170.0
# Musical Instruments   53359055.0
# Web Development      630843775.0

# %%
grouppedProfit.plot(kind='bar',rot=45)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='subject',y='Profit',data=df,hue='subject',ci=None)
plt.show()

# %%
df['is_paid'].describe()
# Out:
# count     3682
# unique       4
# top       True
# freq      2738
# Name: is_paid, dtype: object

# %%
df['is_paid'].unique()
# Out:
# array(['True', 'False', 'FALSE', 'TRUE'], dtype=object)

# %%
paid_dict={'True':True,'TRUE':True,'False':False,'FALSE':False} #make it 2 values only instead of 4

# %%
df['is_paid']=df['is_paid'].map(paid_dict)

# %%
df['is_paid'].unique()
# Out:
# array([ True, False])

# %%
df['is_paid'].value_counts()
# Out:
# True     3372
# False     310
# Name: is_paid, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind='pie')
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.countplot(x=df['is_paid'])
plt.show() #using seaborn

# %%
grouppedpied=pd.DataFrame(df.groupby('is_paid')['subject'].value_counts())
grouppedpied
# Out:
#                              subject
# is_paid subject
# False   Web Development          133
#         Business Finance          96
#         Musical Instruments       46
#         Graphic Design            35
# True    Business Finance        1103
#         Web Development         1067
#         Musical Instruments      634
#         Graphic Design           568

# %%
grouppedpied.plot(kind='barh')
plt.show()

# %%
df['course_title'].str.len()
# Out:
# 0       34
# 1       59
# 2       56
# 3       50
# 4       44
#         ..
# 3678    56
# 3679    55
# 3680    29
# 3681    54
# 3682    52
# Name: course_title, Length: 3682, dtype: int64

# %%
df['course_title_len']=df['course_title'].str.len()

# %%
df['course_title_len'].max()
# Out:
# 243

# %%
df['course_title_len'].min()
# Out:
# 6

# %%
df['course_title_len'].idxmax()
# Out:
# 2191

# %%
df.loc[2191]
# Out:
# course_id                                                         286898
# course_title           Aprende a tocar el Acordeón 'de oído y con téc...
# url                    https://www.udemy.com/aprende-los-secretos-de-...
# is_paid                                                             True
# price                                                               75.0
# num_subscribers                                                      158
# num_reviews                                                           17
# num_lectures                                                          59
# level                                                         All Levels
# content_duration                                               2.5 hours
# published_timestamp                                 2014-07-28T13:55:43Z
# subject                                              Musical Instruments
# clean_course_title     Aprende tocar el Acorden de odo con tcnicahttp...
# ...

# %%
df['published_timestamp']
# Out:
# 0       2017-01-18T20:58:58Z
# 1       2017-03-09T16:34:20Z
# 2       2016-12-19T19:26:30Z
# 3       2017-05-30T20:07:24Z
# 4       2016-12-13T14:57:18Z
#                 ...
# 3678    2016-06-14T17:36:46Z
# 3679    2017-03-10T22:24:30Z
# 3680    2015-12-30T16:41:42Z
# 3681    2016-08-11T19:06:15Z
# 3682    2014-09-28T19:51:11Z
# Name: published_timestamp, Length: 3682, dtype: object

# %%
df['published_timestamp'].str.split('T') #to seprate date and time
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3678    [2016-06-14, 17:36:46Z]
# 3679    [2017-03-10, 22:24:30Z]
# 3680    [2015-12-30, 16:41:42Z]
# 3681    [2016-08-11, 19:06:15Z]
# 3682    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3682, dtype: object

# %%
df['published_date']=df['published_timestamp'].str.split('T').str.get(0) #to seprate date and time and get date only , time is not necessary 
df['published_date']
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3678    2016-06-14
# 3679    2017-03-10
# 3680    2015-12-30
# 3681    2016-08-11
# 3682    2014-09-28
# Name: published_date, Length: 3682, dtype: object

# %%
df['published_date']=pd.to_datetime(df['published_date'],format='%Y-%m-%d') #convert time from object to date as data type
df['published_date']
# Out:
# 0      2017-01-18
# 1      2017-03-09
# 2      2016-12-19
# 3      2017-05-30
# 4      2016-12-13
#           ...
# 3678   2016-06-14
# 3679   2017-03-10
# 3680   2015-12-30
# 3681   2016-08-11
# 3682   2014-09-28
# Name: published_date, Length: 3682, dtype: datetime64[ns]

# %%
df['year']=df['published_date'].dt.year
df['month']=df['published_date'].dt.month
df['day']=df['published_date'].dt.day #seprate year , month and day to 3 columns

# %%
df['year'].unique()
# Out:
# array([2017, 2016, 2014, 2015, 2013, 2012, 2011], dtype=int64)

# %%
df.groupby('year')['num_subscribers'].sum()
# Out:
# year
# 2011     119028
# 2012     555339
# 2013    1723438
# 2014    1930406
# 2015    3475324
# 2016    2966644
# 2017     990977
# Name: num_subscribers, dtype: int64

# %%
df.groupby('year')['num_subscribers'].sum().plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='year',y='num_subscribers',data=df,hue='subject',ci= None)
plt.title('Plot of Subscription per year per Subject Category')
plt.show()#using seaborn
